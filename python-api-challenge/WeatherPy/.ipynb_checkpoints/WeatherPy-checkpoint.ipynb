# %%
import json
import requests
import citipy
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

api_key = "d3e324f57e32b7cf1ca934b35055e7af"
weather_url = "https://api.openweathermap.org/data/2.5/weather?appid=" + api_key +"&units=imperial"

# %%
cities_list = pd.read_csv("worldcities.csv")
cities_sample = cities_list.sample(500)

#lat, lng
#temp in F ['main']['temp'] 
#humidity(%) ['main']['humidity'] 
#cloudiness(%),  ['clouds']['all']
#wind speed(mph) ['wind']['speed']
#cities_sample['Temperature (F)'], cities_sample['Humidity (%)'], cities_sample['Cloudiness (%)'], cities_sample['Wind Speed (mph)'] = "", "", "", ""
cities_sample.head()
# Out:
#       Country          City   Latitude  Longitude
# 36843      ru  lokomotivnyy  53.011800  60.568400
# 7083       co      monteria   8.747984 -75.881428
# 41882      ua     yamnytsya  48.989722  24.707500
# 24797      mx     tultitlan  19.647222 -99.170833
# 42746      us      trumbull  41.242778 -73.201111

# %%
for index, row in cities_sample.iterrows():
    city = row['City'].title()
    country = row['Country'].upper()
    results = requests.get(weather_url + "&q=" + city + "," + country).json()
    print(f"Getting Weather Info from {city.title()} {index}, {country.upper()}.")
    
    try:
        cities_sample.loc[index, 'City'] = city
        cities_sample.loc[index, 'Country'] = country
        cities_sample.loc[index, 'Temperature (F)'] = results['main']['temp']
        cities_sample.loc[index, 'Humidity (%)'] = results['main']['humidity']
        cities_sample.loc[index, 'Cloudiness (%)'] = results['clouds']['all']
        cities_sample.loc[index, 'Wind Speed (mph)'] = results['wind']['speed']
    except:
        print(f"Not Enough Weather Info for {city} {index}, {country}")
# Out:
# Getting Weather Info from Lokomotivnyy 36843, RU.
# Getting Weather Info from Monteria 7083, CO.
# Getting Weather Info from Yamnytsya 41882, UA.
# Getting Weather Info from Tultitlan 24797, MX.
# Getting Weather Info from Trumbull 42746, US.
# Getting Weather Info from Gaoual 13265, GN.
# Getting Weather Info from Soron 19494, IN.
# Getting Weather Info from Ithaki 13619, GR.
# Getting Weather Info from Yachihuacaltepec 24894, MX.
# Getting Weather Info from Mogadouro 31677, PT.
# Getting Weather Info from Palm Springs 42953, US.
# Getting Weather Info from Vilaka 22678, LV.
# Not Enough Weather Info for Vilaka 22678, LV
# Getting Weather Info from Meshchovsk 37008, RU.
# Getting Weather Info from Trinitapoli 21082, IT.
# Getting Weather Info from Phibun Mangsahan 40245, TH.
# Getting Weather Info from Frankfort 46593, ZA.
# Getting Weather Info from Pueblo Nuevo Solistahuacan 24337, MX.
# Getting Weather Info from Caarapo 2556, BR.
# Getting Weather Info from Tolland 42744, US.
# Getting Weather Info from Moji Das Cruzes 3407, BR.
# Not Enough Weather Info for Moji Das Cruzes 3407, BR
# Getting Weather Info from Oltu 40673, TR.
# Getting Weather Info from Sevan 357, AM.
# Getting Weather Info from Rialma 3787, BR.
# Getting Weather Info from Kandi 18107, IN.
# Getting Weather Info from Lund 39447, SE.
# Getting Weather Info from Bavaniste 34832, RS.
# Getting Weather Info from Cloquet 44146, US.
# Getting Weather Info from Tungawan 30586, PH.
# Getting Weather Info from Savda 19335, IN.
# Getting Weather Info from Nova Vicosa 3497, BR.
# Getting Weather Info from Urbana 45129, US.
# Getting Weather Info from Sindang 16496, ID.
# Getting Weather Info from Dekar 4304, BW.
# Getting Weather Info from Navatat 29238, PH.
# Getting Weather Info from Mukono 41999, UG.
# Getting Weather Info from Dzepciste 22862, MK.
# Getting Weather Info from Sabha 21197, JO.
# Getting Weather Info from Oume 5606, CI.
# Getting Weather Info from Taramangalam 19565, IN.
# Getting Weather Info from Elasson 13518, GR.
# Not Enough Weather Info for Elasson 13518, GR
# Getting Weather Info from Quezon 29617, PH.
# Getting Weather Info from Pembroke 44465, US.
# Getting Weather Info from Renala Khurd 30941, PK.
# Getting Weather Info from Monze 46778, ZM.
# Getting Weather Info from Volno-Nadezhdinskoye 38955, RU.
# Getting Weather Info from Mulanje 23259, MW.
# Getting Weather Info from Zakupy 8410, CZ.
# Getting Weather Info from Shively 43611, US.
# Getting Weather Info from Luganville 46458, VU.
# Getting Weather Info from Antunez 23378, MX.
# Getting Weather Info from Decin 7905, CZ.
# Getting Weather Info from Campinas 2611, BR.
# Getting Weather Info from Bucsa 15442, HU.
# Getting Weather Info from Passaic 44591, US.
# Getting Weather Info from Tikamgarh 19605, IN.
# Getting Weather Info from Lujan 498, AR.
# Getting Weather Info from Tierra Colorada 24699, MX.
# Getting Weather Info from Cernat 32612, RO.
# Getting Weather Info from Maplewood 44177, US.
# Getting Weather Info from Witten 9869, DE.
# Getting Weather Info from Facatativa 6854, CO.
# Getting Weather Info from Dvin 236, AM.
# Getting Weather Info from Brastavatu 32435, RO.
# Getting Weather Info from Buston 40347, TJ.
# Getting Weather Info from Xiropotamos 14383, GR.
# Getting Weather Info from Rokiskis 22421, LT.
# Getting Weather Info from Nolinsk 37265, RU.
# Getting Weather Info from Nahawan 29200, PH.
# Getting Weather Info from San Juan De Uraba 7317, CO.
# Getting Weather Info from Pias 29489, PH.
# Getting Weather Info from Samana 7277, CO.
# Not Enough Weather Info for Samana 7277, CO
# Getting Weather Info from Teocaltiche 24631, MX.
# Getting Weather Info from Nangomba 41052, TZ.
# Getting Weather Info from Jibuti 9909, DJ.
# Getting Weather Info from Yuzhnyy 39168, RU.
# Getting Weather Info from Kundiawa 26898, PG.
# Getting Weather Info from Kunnamkulam 18378, IN.
# Getting Weather Info from Batuan 27379, PH.
# Getting Weather Info from Talin 376, AM.
# Getting Weather Info from Neumunster 9360, DE.
# Getting Weather Info from Lugovaya 36864, RU.
# Getting Weather Info from Zinder 25219, NE.
# Getting Weather Info from Longjiang 6172, CN.
# Getting Weather Info from Nova Vodolaha 41535, UA.
# Getting Weather Info from Javalera 28380, PH.
# Getting Weather Info from Engenheiro Beltrao 2857, BR.
# Getting Weather Info from Bolshaya Chernigovka 35451, RU.
# Not Enough Weather Info for Bolshaya Chernigovka 35451, RU
# Getting Weather Info from Astrea 6620, CO.
# Getting Weather Info from Kuroiso 21534, JP.
# Getting Weather Info from Montfermeil 11843, FR.
# Getting Weather Info from Zudilovo 39299, RU.
# Getting Weather Info from Katunino 36222, RU.
# Getting Weather Info from Casillas 14427, GT.
# Getting Weather Info from Vernon 45798, US.
# Getting Weather Info from Wayland 43997, US.
# Getting Weather Info from Uzyn 41818, UA.
# Getting Weather Info from Iasmos 13604, GR.
# Getting Weather Info from Idio 28304, PH.
# Getting Weather Info from Itambacuri 3101, BR.
# Getting Weather Info from Qalyub 10615, EG.
# Getting Weather Info from Lourdes 11781, FR.
# Getting Weather Info from Mendeleyevsk 37005, RU.
# Getting Weather Info from Bilimora 17302, IN.
# Getting Weather Info from Lochau 670, AT.
# Getting Weather Info from Voskehask 409, AM.
# Getting Weather Info from Spresiano 21021, IT.
# Getting Weather Info from Sanjwal 30952, PK.
# Getting Weather Info from Mersch 22547, LU.
# Getting Weather Info from Nguiu 910, AU.
# Not Enough Weather Info for Nguiu 910, AU
# Getting Weather Info from Ananas 2331, BR.
# Not Enough Weather Info for Ananas 2331, BR
# Getting Weather Info from Mucuri 3444, BR.
# Getting Weather Info from Wieliczka 31402, PL.
# Getting Weather Info from Badajoz 10698, ES.
# Getting Weather Info from Gourbeyre 13296, GP.
# Getting Weather Info from Puranpur 19069, IN.
# Getting Weather Info from Cotija 23676, MX.
# Not Enough Weather Info for Cotija 23676, MX
# Getting Weather Info from Upala 7655, CR.
# Getting Weather Info from Gigant 35879, RU.
# Getting Weather Info from Charkhari 17396, IN.
# Getting Weather Info from Rokosovo 41664, UA.
# Getting Weather Info from Algonquin 43191, US.
# Getting Weather Info from Hobo 28294, PH.
# Getting Weather Info from Kuttigen 5388, CH.
# Getting Weather Info from Gudur 17784, IN.
# Getting Weather Info from Poitiers 11934, FR.
# Getting Weather Info from Cueto 7695, CU.
# Getting Weather Info from Wrentham 44015, US.
# Getting Weather Info from Chiang Klang 40130, TH.
# Getting Weather Info from Nalvo 29207, PH.
# Getting Weather Info from Shahpur Chakar 30964, PK.
# Getting Weather Info from Hukvaldy 7983, CZ.
# Getting Weather Info from Baluseni 32234, RO.
# Getting Weather Info from Pestisani 33831, RO.
# Getting Weather Info from Langgons 9174, DE.
# Getting Weather Info from Onod 15874, HU.
# Getting Weather Info from San Joaquin 15137, HN.
# Getting Weather Info from Bangkal 27285, PH.
# Getting Weather Info from Skibotn 26050, NO.
# Getting Weather Info from Bhadravati 17219, IN.
# Getting Weather Info from Agnanteron 13332, GR.
# Getting Weather Info from Mapastepec 24084, MX.
# Getting Weather Info from Hirado 21335, JP.
# Getting Weather Info from Barichara 6632, CO.
# Getting Weather Info from Peta 14121, GR.
# Getting Weather Info from Hiroshima 21341, JP.
# Getting Weather Info from Woodburn 45245, US.
# Getting Weather Info from Bakhchysaray 41135, UA.
# Getting Weather Info from Kratovo 36633, RU.
# Getting Weather Info from Saint-Raphael 15332, HT.
# Getting Weather Info from Razole 19202, IN.
# Getting Weather Info from Winterswijk 25735, NL.
# Getting Weather Info from Skelmorlie 12935, GB.
# Getting Weather Info from Dyatkovo 35779, RU.
# Getting Weather Info from Sorata 2237, BO.
# Getting Weather Info from Antipolo 27058, PH.
# Getting Weather Info from Zirgan 39276, RU.
# Getting Weather Info from Thornhill 12997, GB.
# Getting Weather Info from Urayasu 21909, JP.
# Getting Weather Info from Svetogorsk 38445, RU.
# Getting Weather Info from Yermekeyevo 39123, RU.
# Getting Weather Info from Pamplona 29363, PH.
# Getting Weather Info from Hala 30773, PK.
# Getting Weather Info from Balatonszarszo 15393, HU.
# Getting Weather Info from Compiegne 11534, FR.
# Getting Weather Info from Saronno 20954, IT.
# Getting Weather Info from Pechory 37574, RU.
# Getting Weather Info from Curanilahue 5652, CL.
# Getting Weather Info from Labney 28490, PH.
# Getting Weather Info from Khorol 41343, UA.
# Getting Weather Info from Chatsu 17403, IN.
# Not Enough Weather Info for Chatsu 17403, IN
# Getting Weather Info from Juban 28398, PH.
# Getting Weather Info from Dolhesti 32928, RO.
# Getting Weather Info from Miahuatlan 24123, MX.
# Getting Weather Info from Gatun 26430, PA.
# Getting Weather Info from Maloye Verevo 36932, RU.
# Getting Weather Info from Zhuanghe 6544, CN.
# Getting Weather Info from Perove 41604, UA.
# Getting Weather Info from Murten 5433, CH.
# Getting Weather Info from Stubbekobing 10162, DK.
# Getting Weather Info from Omidiyeh 19948, IR.
# Getting Weather Info from Panlaitan 29411, PH.
# Getting Weather Info from Sinolon 30222, PH.
# Getting Weather Info from Opopeo 24239, MX.
# Getting Weather Info from Sabinov 39683, SK.
# Getting Weather Info from Mafeteng 22349, LS.
# Getting Weather Info from La Habra 42365, US.
# Getting Weather Info from Tarimoro 24572, MX.
# Getting Weather Info from Dembi Dolo 11152, ET.
# Getting Weather Info from El Cano 26407, PA.
# Getting Weather Info from Mundu 16401, ID.
# Getting Weather Info from Svolvaer 26099, NO.
# Getting Weather Info from Sikonge 41087, TZ.
# Getting Weather Info from Jiquinlaca 14935, HN.
# Getting Weather Info from Cerro De Pasco 26612, PE.
# Getting Weather Info from Florian 6863, CO.
# Getting Weather Info from Laje 3259, BR.
# Getting Weather Info from Golden Rock 430, AN.
# Not Enough Weather Info for Golden Rock 430, AN
# Getting Weather Info from Brezova 7849, CZ.
# Getting Weather Info from Baar 5277, CH.
# Getting Weather Info from Rawatbhata 19191, IN.
# Getting Weather Info from Upper Klinan 30618, PH.
# Getting Weather Info from Borup 9937, DK.
# Getting Weather Info from Tlalnepantla 24734, MX.
# Getting Weather Info from Tam Ky 46440, VN.
# Getting Weather Info from Provideniya 37810, RU.
# Getting Weather Info from Sovetakan 372, AM.
# Getting Weather Info from Hille 9024, DE.
# Getting Weather Info from Bruchkobel 8641, DE.
# Getting Weather Info from Tahitofalu 16044, HU.
# Not Enough Weather Info for Tahitofalu 16044, HU
# Getting Weather Info from Teguldet 38521, RU.
# Getting Weather Info from Empoli 20390, IT.
# Getting Weather Info from Minien 29144, PH.
# Not Enough Weather Info for Minien 29144, PH
# Getting Weather Info from Nadapuram 18706, IN.
# Getting Weather Info from Sonipat 19489, IN.
# Getting Weather Info from Yushan 6509, CN.
# Getting Weather Info from Minamiashigara 21571, JP.
# Getting Weather Info from Palaifiton 14060, GR.
# Not Enough Weather Info for Palaifiton 14060, GR
# Getting Weather Info from Ostrov 37511, RU.
# Getting Weather Info from Wadi 19774, IN.
# Getting Weather Info from Hessisch Oldendorf 9014, DE.
# Getting Weather Info from Ambikapur 16909, IN.
# Getting Weather Info from Novosilikatnyy 37355, RU.
# Getting Weather Info from Sapa 30160, PH.
# Getting Weather Info from San Francisco 29822, PH.
# Getting Weather Info from Fortrose 12542, GB.
# Getting Weather Info from Sansepolcro 20937, IT.
# Getting Weather Info from Arevashogh 171, AM.
# Getting Weather Info from Slagelse 10133, DK.
# Getting Weather Info from Taboc 30294, PH.
# Getting Weather Info from Bendigo 791, AU.
# Getting Weather Info from Sampang 16479, ID.
# Getting Weather Info from Andira 2335, BR.
# Getting Weather Info from Huangcun 6030, CN.
# Getting Weather Info from Eching 8748, DE.
# Getting Weather Info from San Francisco 29821, PH.
# Getting Weather Info from Vukovar 15301, HR.
# Getting Weather Info from Bath 43666, US.
# Getting Weather Info from Yakshur-Bodya 39051, RU.
# Not Enough Weather Info for Yakshur-Bodya 39051, RU
# Getting Weather Info from Sibi 30973, PK.
# Getting Weather Info from Concepcion 6764, CO.
# Getting Weather Info from Kriftel 9142, DE.
# Getting Weather Info from Manaus 3313, BR.
# Getting Weather Info from Baker City 45199, US.
# Getting Weather Info from Pittem 1714, BE.
# Getting Weather Info from Glinde 8907, DE.
# Getting Weather Info from Tinnanur 19610, IN.
# Getting Weather Info from Hulan Ergi 6045, CN.
# Getting Weather Info from Dumbraveni 32983, RO.
# Getting Weather Info from Gamba 12195, GA.
# Getting Weather Info from Natividad 29232, PH.
# Getting Weather Info from Sagara 21728, JP.
# Getting Weather Info from Baile Tusnad 32196, RO.
# Getting Weather Info from Castelletto Sopra Ticino 20269, IT.
# Getting Weather Info from Cabatuan 27657, PH.
# Getting Weather Info from Hudson Bay 4679, CA.
# Getting Weather Info from Pennsauken 44593, US.
# Getting Weather Info from Annur 16948, IN.
# Getting Weather Info from Alzamay 35146, RU.
# Getting Weather Info from Kesla 992, AZ.
# Not Enough Weather Info for Kesla 992, AZ
# Getting Weather Info from Cojumatlan 23634, MX.
# Not Enough Weather Info for Cojumatlan 23634, MX
# Getting Weather Info from Gokul 17753, IN.
# Getting Weather Info from Tahara 21815, JP.
# Getting Weather Info from Sarai Mir 19305, IN.
# Getting Weather Info from Tczew 31378, PL.
# Getting Weather Info from Narayangarh 18775, IN.
# Getting Weather Info from Mariager 10069, DK.
# Getting Weather Info from Ipil 28341, PH.
# Getting Weather Info from Bala 32202, RO.
# Getting Weather Info from Porto Walter 3731, BR.
# Getting Weather Info from Lorain 45049, US.
# Getting Weather Info from Lemnia 33384, RO.
# Getting Weather Info from Iconha 3014, BR.
# Getting Weather Info from Brigantine 44498, US.
# Getting Weather Info from Jutai 3242, BR.
# Getting Weather Info from Malard 19930, IR.
# Getting Weather Info from Wewak 26917, PG.
# Getting Weather Info from Katipunan 28443, PH.
# Getting Weather Info from Azalea Park 42782, US.
# Getting Weather Info from Aberdeen 45499, US.
# Getting Weather Info from Udaipur 19661, IN.
# Getting Weather Info from Overath 9439, DE.
# Getting Weather Info from Kirkenes 25905, NO.
# Getting Weather Info from Middletown 44789, US.
# Getting Weather Info from Waarschoot 1804, BE.
# Getting Weather Info from Hedaru 40878, TZ.
# Getting Weather Info from Bobrov 35418, RU.
# Getting Weather Info from Coatzintla 23626, MX.
# Getting Weather Info from Sambava 22822, MG.
# Getting Weather Info from Champua 17373, IN.
# Getting Weather Info from Buwenge 41948, UG.
# Getting Weather Info from Palpa 26730, PE.
# Getting Weather Info from Talusan 30387, PH.
# Getting Weather Info from Petit-Bourg 13303, GP.
# Getting Weather Info from Coudekerque-Branche 11539, FR.
# Getting Weather Info from Orda 37483, RU.
# Getting Weather Info from Cazanesti 32590, RO.
# Getting Weather Info from Raduzhnyy 37850, RU.
# Getting Weather Info from Petroussa 14127, GR.
# Getting Weather Info from Mirpur Bathoro 30887, PK.
# Not Enough Weather Info for Mirpur Bathoro 30887, PK
# Getting Weather Info from Arada 14762, HN.
# Getting Weather Info from Langenlois 660, AT.
# Getting Weather Info from Kollumerland 25587, NL.
# Not Enough Weather Info for Kollumerland 25587, NL
# Getting Weather Info from Mersin 40654, TR.
# Getting Weather Info from Uglovka 38696, RU.
# Getting Weather Info from Juneau 42082, US.
# Getting Weather Info from Gjusvik 25846, NO.
# Not Enough Weather Info for Gjusvik 25846, NO
# Getting Weather Info from Behshahr 19861, IR.
# Getting Weather Info from Kitapok 28476, PH.
# Not Enough Weather Info for Kitapok 28476, PH
# Getting Weather Info from Patao 29452, PH.
# Getting Weather Info from Bridgton 43671, US.
# Getting Weather Info from Lindas 25943, NO.
# Getting Weather Info from Florida 45368, US.
# Getting Weather Info from Hartford 46108, US.
# Getting Weather Info from Patan 18952, IN.
# Getting Weather Info from Sao Roque 4017, BR.
# Getting Weather Info from Shchebetovka 41703, UA.
# Getting Weather Info from Ungheni 34583, RO.
# Getting Weather Info from Ina 21372, JP.
# Getting Weather Info from Wecker 22602, LU.
# Getting Weather Info from Kabrai 18046, IN.
# Getting Weather Info from Miharu 21565, JP.
# Getting Weather Info from Kadom 36093, RU.
# Getting Weather Info from Ostrogozhsk 37509, RU.
# Getting Weather Info from Ibicarai 2997, BR.
# Getting Weather Info from Posta Calnau 33926, RO.
# Getting Weather Info from La Union 24042, MX.
# Getting Weather Info from Marang 25033, MY.
# Getting Weather Info from Amod 16919, IN.
# Getting Weather Info from Villanueva De La Serena 11106, ES.
# Getting Weather Info from La Fortuna 28504, PH.
# Getting Weather Info from Alapur 16871, IN.
# Getting Weather Info from Hangzhou 5996, CN.
# Getting Weather Info from Baliuag 27236, PH.
# Getting Weather Info from Laarne 1602, BE.
# Getting Weather Info from Laguilayan 28510, PH.
# Getting Weather Info from Barashevo 35285, RU.
# Getting Weather Info from Casambalangan 27859, PH.
# Getting Weather Info from Norwalk 42445, US.
# Getting Weather Info from Anqing 5818, CN.
# Getting Weather Info from Camias 27770, PH.
# Getting Weather Info from Genthin 8886, DE.
# Getting Weather Info from Parksepa 10501, EE.
# Getting Weather Info from North Atlanta 43103, US.
# Getting Weather Info from Attock 30679, PK.
# Getting Weather Info from New Baltimore 44089, US.
# Getting Weather Info from Buchs 5304, CH.
# Getting Weather Info from Arequipa 26583, PE.
# Getting Weather Info from Bergkamen 8577, DE.
# Getting Weather Info from Remigio 3777, BR.
# Getting Weather Info from Shushtar 19991, IR.
# Getting Weather Info from Dealu Morii 32883, RO.
# Getting Weather Info from Patos 120, AL.
# Getting Weather Info from Vinzons 30649, PH.
# Getting Weather Info from Kalengwa 46752, ZM.
# Getting Weather Info from Chanute 43536, US.
# Getting Weather Info from Tambo Grande 26809, PE.
# Getting Weather Info from Floha 8825, DE.
# Getting Weather Info from Kuusamo 11254, FI.
# Getting Weather Info from Nizhneangarsk 37225, RU.
# Getting Weather Info from Manito 29017, PH.
# Getting Weather Info from Castelfiorentino 20257, IT.
# Getting Weather Info from Nerekhta 37185, RU.
# Getting Weather Info from Manastirea 33497, RO.
# Getting Weather Info from Manglisi 13110, GE.
# Getting Weather Info from Krivogastani 22880, MK.
# Getting Weather Info from Jabinyanah 40424, TN.
# Getting Weather Info from Reina Mercedes 29649, PH.
# Getting Weather Info from Novoshakhtinsk 37351, RU.
# Getting Weather Info from Dendermonde 1462, BE.
# Getting Weather Info from Stokmarknes 26082, NO.
# Getting Weather Info from Charleston 43228, US.
# Getting Weather Info from Toulon 12106, FR.
# Getting Weather Info from Domoszlo 15507, HU.
# Getting Weather Info from Guelengdeng 40050, TD.
# Not Enough Weather Info for Guelengdeng 40050, TD
# Getting Weather Info from Coxcatlan 23677, MX.
# Getting Weather Info from Rockland 43964, US.
# Getting Weather Info from Palampur 18885, IN.
# Getting Weather Info from Kaliganj 1298, BD.
# Getting Weather Info from Mitchelstown 16682, IE.
# Getting Weather Info from Makueni 22015, KE.
# Getting Weather Info from Aybak 15, AF.
# Not Enough Weather Info for Aybak 15, AF
# Getting Weather Info from Topolovgrad 2079, BG.
# Getting Weather Info from Hun 22689, LY.
# Getting Weather Info from Geneva 44744, US.
# Getting Weather Info from Oxnard 42459, US.
# Getting Weather Info from Morlenbach 9320, DE.
# Getting Weather Info from Drancy 11573, FR.
# Getting Weather Info from Hohhot 6014, CN.
# Getting Weather Info from Pichataro 24301, MX.
# Getting Weather Info from Oliveira Do Douro 31702, PT.
# Getting Weather Info from Yekaterinogradskaya 39092, RU.
# Getting Weather Info from Campanha 2607, BR.
# Getting Weather Info from Robore 2215, BO.
# Getting Weather Info from Borujerd 19867, IR.
# Getting Weather Info from Namboongan 29210, PH.
# Getting Weather Info from Mojiman 15031, HN.
# Getting Weather Info from Kyabe 40053, TD.
# Getting Weather Info from Arazap 166, AM.
# Getting Weather Info from Zalari 39179, RU.
# Getting Weather Info from Sevres 12073, FR.
# Getting Weather Info from Porto Calvo 3717, BR.
# Getting Weather Info from Toma 1891, BF.
# Getting Weather Info from Udpura 19669, IN.
# Getting Weather Info from Potrero Del Llano 24323, MX.
# Getting Weather Info from Santa Teresa 24505, MX.
# Getting Weather Info from Tagasilay 30323, PH.
# Getting Weather Info from Caineni 32519, RO.
# Not Enough Weather Info for Caineni 32519, RO
# Getting Weather Info from Priolo Gargallo 20821, IT.
# Getting Weather Info from Amfissa 13372, GR.
# Getting Weather Info from Verenchanka 41839, UA.
# Getting Weather Info from Gorlitz 8912, DE.
# Getting Weather Info from Togane 21858, JP.
# Getting Weather Info from Vrede 46719, ZA.
# Getting Weather Info from Brenham 45606, US.
# Getting Weather Info from La Gaulette 23176, MU.
# Not Enough Weather Info for La Gaulette 23176, MU
# Getting Weather Info from El Monte 42301, US.
# Getting Weather Info from Bargaoani 32258, RO.
# Getting Weather Info from Bwanga 40863, TZ.
# Getting Weather Info from Shebekino 38114, RU.
# Getting Weather Info from Las Mercedes 14988, HN.
# Getting Weather Info from Luza 36878, RU.
# Getting Weather Info from Northbridge 43947, US.
# Getting Weather Info from Gerga 35872, RU.
# Getting Weather Info from Ballsh 77, AL.
# Getting Weather Info from Lanna 28554, PH.
# Getting Weather Info from Paraiso 26503, PA.
# Getting Weather Info from Azar Shahr 19849, IR.
# Not Enough Weather Info for Azar Shahr 19849, IR
# Getting Weather Info from Tamalin 24547, MX.
# Getting Weather Info from Manggahan 29004, PH.
# Getting Weather Info from Santa Rosa 42552, US.
# Getting Weather Info from Khalandrion 13728, GR.
# Getting Weather Info from Paulista 3605, BR.
# Getting Weather Info from Adancata 32069, RO.
# Getting Weather Info from Villanueva 15237, HN.
# Getting Weather Info from Vernon 12141, FR.
# Getting Weather Info from Menuma 21562, JP.
# Getting Weather Info from Melur 18618, IN.
# Getting Weather Info from Cambridge 12371, GB.
# Getting Weather Info from Saginaw 45764, US.
# Getting Weather Info from Luchegorsk 36862, RU.
# Getting Weather Info from Pirayu 31979, PY.
# Getting Weather Info from Skagastrond 20029, IS.
# Not Enough Weather Info for Skagastrond 20029, IS
# Getting Weather Info from Vlist 25715, NL.
# Getting Weather Info from Pielesti 33846, RO.
# Getting Weather Info from Vendryne 8379, CZ.
# Getting Weather Info from Lunavada 18439, IN.
# Getting Weather Info from Seuzach 5490, CH.
# Getting Weather Info from Abatskoye 35053, RU.
# Getting Weather Info from Pervomayskiy 37597, RU.
# Getting Weather Info from Sidi Bu Zayd 40459, TN.
# Not Enough Weather Info for Sidi Bu Zayd 40459, TN
# Getting Weather Info from Toki 21861, JP.
# Getting Weather Info from Mogos 33611, RO.
# Not Enough Weather Info for Mogos 33611, RO
# Getting Weather Info from Bossier City 43621, US.
# Getting Weather Info from Tual 16555, ID.
# Getting Weather Info from Smithtown 44849, US.
# Getting Weather Info from Guio-Ang 28244, PH.
# Not Enough Weather Info for Guio-Ang 28244, PH
# Getting Weather Info from Atiquizaya 39900, SV.
# Getting Weather Info from Hasanabad 987, AZ.
# Not Enough Weather Info for Hasanabad 987, AZ
# Getting Weather Info from Stavanger 26077, NO.
# Getting Weather Info from Salvacion 29718, PH.
# Getting Weather Info from Buhatan 27558, PH.
# Getting Weather Info from Kerema 26892, PG.
# Getting Weather Info from Sassandra 5609, CI.
# Getting Weather Info from Bandarban 1268, BD.
# Getting Weather Info from Karlovo 1968, BG.
# Getting Weather Info from Garchitorena 28188, PH.
# Getting Weather Info from Cherepanovo 35597, RU.
# Getting Weather Info from Berlaar 1394, BE.
# Getting Weather Info from Catalina Foothills 42099, US.
# Getting Weather Info from Alac 26961, PH.
# Getting Weather Info from Lysogorskaya 36887, RU.
# Getting Weather Info from Atouguia Da Baleia 31504, PT.
# Getting Weather Info from Moravska Trebova 8129, CZ.
# Getting Weather Info from Kikuyu 21997, KE.
# Getting Weather Info from Ljaskovec 1995, BG.
# Not Enough Weather Info for Ljaskovec 1995, BG
# Getting Weather Info from Roverud 26021, NO.
# Getting Weather Info from Spring 45780, US.
# Getting Weather Info from Apeldoorn 25453, NL.
# Getting Weather Info from Essen 1489, BE.
# Getting Weather Info from Worth 43409, US.
# Getting Weather Info from Sarti 14211, GR.
# Getting Weather Info from Tlaltenango 24738, MX.
# Getting Weather Info from Oltenita 33733, RO.
# Getting Weather Info from Santa Rita 46374, VE.
# Getting Weather Info from Warendorf 9806, DE.
# Getting Weather Info from Magyarbanhegyes 15764, HU.
# Getting Weather Info from Lawan Kuda Baharu 25030, MY.
# Not Enough Weather Info for Lawan Kuda Baharu 25030, MY
# Getting Weather Info from Samtredia 13120, GE.
# Getting Weather Info from Gogosari 33166, RO.
# Getting Weather Info from Tuburan 30561, PH.
# Getting Weather Info from Krasnoye 36595, RU.
# Getting Weather Info from Celldomolk 15455, HU.
# Getting Weather Info from Makrinitsa 13883, GR.
# Getting Weather Info from Yafran 22707, LY.
# Getting Weather Info from Igurusi 40883, TZ.
# Getting Weather Info from Drawsko Pomorskie 31081, PL.
# Getting Weather Info from Lysyye Gory 36889, RU.
# Getting Weather Info from Warrenton 46723, ZA.
# Getting Weather Info from Flora 28162, PH.
# Getting Weather Info from Antofagasta 5627, CL.

# %%
cities_sample = cities_sample.dropna()

# %%
#Temperature vs Latitude Scatter
plt.scatter(cities_sample['Latitude'], cities_sample['Temperature (F)'])
plt.xlabel('Latitude'), plt.ylabel('Temperature (F)'), plt.title('Temperature (F) vs Latitude')
print("Using this plot, we can see that the closer you get towards the Equator, it gets hotter")
plt.savefig('Images/TempLatScatter.png')
# Out:
# Using this plot, we can see that the closer you get towards the Equator, it gets hotter

# %%
#Humidity (%) vs. Latitude scatter
plt.scatter(cities_sample['Latitude'], cities_sample['Humidity (%)'])
plt.xlabel('Latitude'), plt.ylabel('Humidity (%)'), plt.title("Humidity (%) vs Latitude")
print("Using this plot, we can see that the closer you get towards the Equator, it gets less humid.")
plt.savefig("Images/HumidLatScatter.png")
# Out:
# Using this plot, we can see that the closer you get towards the Equator, it gets less humid.

# %%
#Cloudiness (%) vs. Latitude Scatter
plt.scatter(cities_sample['Latitude'], cities_sample['Cloudiness (%)'])
plt.xlabel('Latitude'), plt.ylabel('Humidity (%)'), plt.title('Cloudiness (%) vs. Latitude')
print("Using this plot, there does not seem to be a relationship between cloudiness and latitude.")
plt.savefig("Images/CloudLatScatter.png")
# Out:
# Using this plot, there does not seem to be a relationship between cloudiness and latitude.

# %%
#Wind Speed (mph) vs. Latitude Scatter
plt.scatter(cities_sample['Latitude'], cities_sample['Wind Speed (mph)'])
plt.xlabel('Latitude'), plt.ylabel('Wind Speed (mph)'), plt.title('Wind Speed (mph) vs. Latitude')
print("Using this plot, we can see that the closer you get towards the Equator, wind speeds get lower.")
plt.savefig("Images/WindLatScatter.png")
# Out:
# Using this plot, we can see that the closer you get towards the Equator, wind speeds get lower.

# %%
#define linear regression function
north_hemi = cities_sample.loc[cities_sample['Latitude'] >= 0 ]
south_hemi = cities_sample.loc[cities_sample['Latitude'] < 0]

def linear_plot(x, y, x_label, y_label, title_name):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    line_regress = x * slope + intercept
    plt.scatter(x, y)
    plt.plot(x, line_regress, "r-")
    plt.xlabel(x_label), plt.ylabel(y_label), plt.title(title_name)

north_hemi.info()
south_hemi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413 entries, 36843 to 28162
# Data columns (total 8 columns):
# Country             413 non-null object
# City                413 non-null object
# Latitude            413 non-null float64
# Longitude           413 non-null float64
# Temperature (F)     413 non-null float64
# Humidity (%)        413 non-null float64
# Cloudiness (%)      413 non-null float64
# Wind Speed (mph)    413 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 29.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 46593 to 5627
# Data columns (total 8 columns):
# Country             55 non-null object
# City                55 non-null object
# Latitude            55 non-null float64
# Longitude           55 non-null float64
# Temperature (F)     55 non-null float64
# Humidity (%)        55 non-null float64
# Cloudiness (%)      55 non-null float64
# Wind Speed (mph)    55 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 3.9+ KB

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude linear
linear_plot(north_hemi['Latitude'], north_hemi['Temperature (F)'], 'Latitude', 'Temperature (F)', 'North Hemi: Temperature (F) vs. Latitude')

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude linear
linear_plot(south_hemi['Latitude'], south_hemi['Temperature (F)'], 'Latitude', 'Temperature (F)', 'South Hemi: Temperature (F) vs. Latitude')

print(f'Naturally on both hemispheres, going closer to the equator means higher temperatures.')
# Out:
# Naturally on both hemispheres, going closer to the equator means higher temperatures.

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude
linear_plot(north_hemi['Latitude'], north_hemi['Humidity (%)'], 'Latitude', 'Humidity (%)', 'North Hemi: Humidity (%) vs. Latitude')

# %%
#South Hemi- Humidity (%) vs Latitude
linear_plot(south_hemi['Latitude'], south_hemi['Humidity (%)'], 'Latitude', 'Humidity (%)', 'South Hemi: Humidity (%) vs. Latitude')

print(f'Humidity in general seems to, on average, slowly increase the more north you get.')
# Out:
# Humidity in general seems to, on average, slowly increase the more north you get.

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
linear_plot(north_hemi['Latitude'], north_hemi['Cloudiness (%)'], 'Latitude', 'Cloudiness (%)', 'North Hemi: Cloudiness (%) vs. Latitude')

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude
linear_plot(south_hemi['Latitude'], south_hemi['Cloudiness (%)'], 'Latitude', 'Cloudiness (%)', 'South Hemi: Cloudiness (%) vs. Latitude')
print(f'While previously there seemed to be no relation, as we go further south, there are lower Cloud percentages.')
# Out:
# While previously there seemed to be no relation, as we go further south, there are lower Cloud percentages.

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
linear_plot(north_hemi['Latitude'], north_hemi['Wind Speed (mph)'], 'Latitude', 'Wind Speed (mph)', 'North Hemi: Wind Speed (mph) vs. Latitude')

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude
linear_plot(south_hemi['Latitude'], south_hemi['Wind Speed (mph)'], 'Latitude', 'Wind Speed (mph)', 'South Hemi: Wind Speed (mph)')
print(f'Based on these plots, the further south or north you go, the higher wind speeds you will encounter')
# Out:
# Based on these plots, the further south or north you go, the higher wind speeds you will encounter

# %%
cities_sample.to_csv("cities_sample.csv")
